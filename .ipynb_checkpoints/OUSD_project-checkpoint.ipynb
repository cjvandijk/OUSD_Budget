# %% [markdown]
# # OUSD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys
sys.path.append('C:\\Users\\Claudia\\Anaconda3\\envs\\py37')
sys.path
# Out:
# ['',
#  'C:\\Users\\Claudia\\Anaconda3\\python36.zip',
#  'C:\\Users\\Claudia\\Anaconda3\\DLLs',
#  'C:\\Users\\Claudia\\Anaconda3\\lib',
#  'C:\\Users\\Claudia\\Anaconda3',
#  'C:\\Users\\Claudia\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\Claudia\\Anaconda3\\lib\\site-packages\\sklearn_pandas-1.7.0-py3.6.egg',
#  'C:\\Users\\Claudia\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Claudia\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Claudia\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Claudia\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Claudia\\.ipython',
#  'C:\\Users\\Claudia\\Anaconda3\\envs\\py37']

# %% [markdown]
# ### Read Budget Data
# Remove rows not related to central offices

# %%
df = pd.read_csv('data/OUSD Budget Data.csv', skiprows = 1)
df.columns = ['Fund', 'Resource_Type', 'Resource', 'Site_Type', 'Site', 'Budget_Category', 'Budget', 'Actual_Spent', 'Encumbrance', 'Balance']

df = df[df['Site'].astype(str).str[0] == '9']  # Remove rows not related to central offices
df.head(3)
# Out:
#                 Fund Resource_Type                               Resource  \
# 0  01 - GENERAL FUND    RESTRICTED  3010 - IASA-I BASIC GRANTS LOW INCOME
# 1  01 - GENERAL FUND    RESTRICTED  3010 - IASA-I BASIC GRANTS LOW INCOME
# 2  01 - GENERAL FUND    RESTRICTED  3010 - IASA-I BASIC GRANTS LOW INCOME
#
#        Site_Type                         Site  \
# 0  District Wide  999 - Districtwide Expenses
# 1  District Wide  999 - Districtwide Expenses
# 2  District Wide  999 - Districtwide Expenses
#
#                      Budget_Category      Budget Actual_Spent Encumbrance  \
# 0         4392 - MID-YEAR ADJUSTMENT  ($303,925)          $0          $0
# 1                     4399 - SURPLUS         $0           $0          $0
# 2  7310 - INTERPROGRAM SUPPORT/COSTS   $951,400           $0          $0
#
#          Balance
# 0  ($303,925.37)
# 1         $0.00
# 2   $951,400.00

# %% [markdown]
# ### Convert Budget and Actual_Spent Columns to Numeric Values

# %%
# replace characters in Budget column that come from excel exports, leaving just the numbers
df['Budget'] = df['Budget'].replace({'\$':'', ',': '', 
                                     '\)':'', '\(':'-'
                                    }, regex = True)

df['Budget'].fillna(0, inplace=True)    # replace NaN values with 0
df['Budget'] = df['Budget'].astype(int).fillna(0)    # convert Budget column to integer

# %%
# replace characters in Actual_Spent column that come from excel exports, leaving just the numbers
df['Actual_Spent'] = df['Actual_Spent'].replace({'\$':'', ',': '', 
                                                 '\)':'', '\(':'-'
                                                }, regex = True)

df['Actual_Spent'].fillna(0, inplace=True)    # replace NaN values with 0
df['Actual_Spent'] = df['Actual_Spent'].astype(int).fillna(0)    # convert Actual_Spent column to integer

# %% [markdown]
# ### Create a dataframe with one line per Site, summing Budget amounts for that Site

# %%
df_grouped = df.groupby('Site', as_index = False)["Budget"].sum()
df_grouped.head()
# Out:
#                                    Site   Budget
# 0            901 - Chief Org Eff & Cul.   708859
# 1                902 - Accounts Payable   895003
# 2  903 - Office of Chief Academic offic  1158483
# 3  905 - Office of Sr. Business Officer   536463
# 4                       906 - Ombudsman   269540

# %% [markdown]
# ### Read Principal Critical-Rating Data (partial at this point)
# I created a separate csv file mapping the categories in the principal's list to categories from budget data. There could be errors, and I could not determine a mapping for some categories.

# %%
df_critical = pd.read_csv('data/map_budget_to_principal_list.csv')
del df_critical["Notes"]  # the notes column is irrelevant to this task, and is mostly NaN
df_critical.head()
# Out:
#                   Budget_Category Principal_Category  Critical_Rating
# 0     999 - Districtwide Expenses                NaN              NaN
# 1  998 - School Contingency Funds                NaN              NaN
# 2            995 - Transportation     Transportation             60.0
# 3    994 - OUSD Police Department    Police Services             54.0
# 4    992 - WAREHOUSE DISTRIBUTION                NaN              NaN

# %% [markdown]
# ### Merge in the Principal Critical Ratings

# %%
df_with_critical = pd.merge(df_grouped, df_critical, how='right', 
                            left_on = 'Site', right_on = 'Budget_Category', 
                            left_index = False, right_index = False, sort=False)
df_final = df_with_critical.dropna().copy()   # remove rows with no principal rating
df_final.head()
# Out:
#                                 Site     Budget  \
# 0         901 - Chief Org Eff & Cul.   708859.0
# 1             902 - Accounts Payable   895003.0
# 5           907 - Student Assignment  1787223.0
# 6          909 - Teaching & Learning  8403763.0
# 7  910 - EARLY CHILDHOOD DEVELOPMENT  7484859.0
#
#                      Budget_Category            Principal_Category  \
# 0         901 - Chief Org Eff & Cul.  Organizational Effectiveness
# 1             902 - Accounts Payable              Accounts Payable
# 5           907 - Student Assignment      School Enrollment Office
# 6          909 - Teaching & Learning     Academics & Instructional
# 7  910 - EARLY CHILDHOOD DEVELOPMENT               Early Childhood
#
#    Critical_Rating
# 0             17.0
# 1             77.0
# 5             75.0
# 6             45.0
# 7             42.0

# %%
df_final['Budget_Percent'] = df_final['Budget'] / df_final['Budget'].sum() * 500
df_final.head()

# This produced a SettingWithCopyWarning. Explanation of this warning can be found at dataquest:
# https://www.dataquest.io/blog/settingwithcopywarning/
# The problem for me was that I was unknowingly working with a view of the dataset, not a copy. 
# Solution: force a copy when creating df_final in the cell above.
# Out:
#                                     Site      Budget  \
# 52              989 - Custodial Services   1498145.0
# 51             988 - Buildings & Grounds  14199558.0
# 48                         983 - Payroll    962511.0
# 25  944 - Human Resources Services, Supp   4761716.0
# 23    941 - Office of the Superintendent   1623061.0
#
#                          Budget_Category       Principal_Category  \
# 52              989 - Custodial Services       Custodial Services
# 51             988 - Buildings & Grounds       Building & Grounds
# 48                         983 - Payroll                  Payroll
# 25  944 - Human Resources Services, Supp                   Talent
# 23    941 - Office of the Superintendent  Superintendent's Office
#
#     Critical_Rating  Budget_Percent
# 52             94.0        4.666700
# 51             88.0       44.231419
# 48             83.0        2.998208
# 25             83.0       14.832677
# 23             82.0        5.055812

# %% [markdown]
# ### Show Initial Plot - side-by-side bar chart

# %%
df_final = df_final.sort_values(by=['Critical_Rating'], ascending=False) 
ax = df_final[['Budget_Percent','Critical_Rating']].plot(kind='bar', title ="Budget vs. Criticality", 
                                                         figsize=(15, 10), legend=True, fontsize=12)
ax.set_ylabel("Relative Values", fontsize=12)
ax.set_xticklabels(df_final['Site'])
plt.show()

# %% [markdown]
# #### Remove Outlier
# This category was quite a bit more in cost than any others and is 2nd from highest position in importance. It skews the scatter plot so that quadrants cannot be clearly demarcated. Outlier thus removed.

# %%
df_final = df_final[~df_final['Budget_Category'].str.startswith('975')]

# %%
plt.rcParams['figure.figsize'] = (13.0, 9.0)
colors = np.random.rand(len(df_final))

plt.scatter(df_final['Budget'], df_final['Critical_Rating'], c=colors, s=600, alpha=0.5)  # , s=area, c=colors,
plt.title('Cost vs. Value')
plt.xlabel='Cost'
plt.ylabel='Value'
plt.grid()
plt.show()

# %%
json_obj = df_final.to_json(orient="table")
json_obj = json_obj.replace("\\", "")
import json
pretty_obj = json.dumps(json_obj)
print(pretty_obj)
# Out:
# "{\"schema\": {\"fields\":[{\"name\":\"index\",\"type\":\"integer\"},{\"name\":\"Site\",\"type\":\"string\"},{\"name\":\"Budget\",\"type\":\"number\"},{\"name\":\"Budget_Category\",\"type\":\"string\"},{\"name\":\"Principal_Category\",\"type\":\"string\"},{\"name\":\"Critical_Rating\",\"type\":\"number\"},{\"name\":\"Budget_Percent\",\"type\":\"number\"}],\"primaryKey\":[\"index\"],\"pandas_version\":\"0.20.0\"}, \"data\": [{\"index\":52,\"Site\":\"989 - Custodial Services\",\"Budget\":1498145.0,\"Budget_Category\":\"989 - Custodial Services\",\"Principal_Category\":\"Custodial Services\",\"Critical_Rating\":94.0,\"Budget_Percent\":4.6667001798},{\"index\":51,\"Site\":\"988 - Buildings & Grounds\",\"Budget\":14199558.0,\"Budget_Category\":\"988 - Buildings & Grounds\",\"Principal_Category\":\"Building & Grounds\",\"Critical_Rating\":88.0,\"Budget_Percent\":44.2314194361},{\"index\":48,\"Site\":\"983 - Payroll\",\"Budget\":962511.0,\"Budget_Category\":\"983 - Payroll\",\"Principal_Category\":\"Payroll\",\"Critical_Rating\":83.0,\"Budget_Percent\":2.998207955},{\"index\":25,\"Site\":\"944 - Human Resources Services, Supp\",\"Budget\":4761716.0,\"Budget_Category\":\"944 - Human Resources Services, Supp\",\"Principal_Category\":\"Talent\",\"Critical_Rating\":83.0,\"Budget_Percent\":14.8326770194},{\"index\":23,\"Site\":\"941 - Office of the Superintendent\",\"Budget\":1623061.0,\"Budget_Category\":\"941 - Office of the Superintendent\",\"Principal_Category\":\"Superintendent's Office\",\"Critical_Rating\":82.0,\"Budget_Percent\":5.0558117275},{\"index\":20,\"Site\":\"936 - Accounting\",\"Budget\":1835213.0,\"Budget_Category\":\"936 - Accounting\",\"Principal_Category\":\"Fiscal Services\",\"Critical_Rating\":78.0,\"Budget_Percent\":5.7166621635},{\"index\":54,\"Site\":\"991 - Food Service\",\"Budget\":6854385.0,\"Budget_Category\":\"991 - Food Service\",\"Principal_Category\":\"Nutrition Services\",\"Critical_Rating\":77.0,\"Budget_Percent\":21.3513109289},{\"index\":1,\"Site\":\"902 - Accounts Payable\",\"Budget\":895003.0,\"Budget_Category\":\"902 - Accounts Payable\",\"Principal_Category\":\"Accounts Payable\",\"Critical_Rating\":77.0,\"Budget_Percent\":2.7879215036},{\"index\":5,\"Site\":\"907 - Student Assignment\",\"Budget\":1787223.0,\"Budget_Category\":\"907 - Student Assignment\",\"Principal_Category\":\"School Enrollment Office\",\"Critical_Rating\":75.0,\"Budget_Percent\":5.5671740021},{\"index\":43,\"Site\":\"968 - Health Services (Nurses)\",\"Budget\":3676574.0,\"Budget_Category\":\"968 - Health Services (Nurses)\",\"Principal_Category\":\"Health Services (Nurses)\",\"Critical_Rating\":74.0,\"Budget_Percent\":11.4524752589},{\"index\":29,\"Site\":\"948 - Research Assessment & Data\",\"Budget\":2489433.0,\"Budget_Category\":\"948 - Research Assessment & Data\",\"Principal_Category\":\"Research Assessment & Data\",\"Critical_Rating\":71.0,\"Budget_Percent\":7.7545480769},{\"index\":24,\"Site\":\"942 - Labor Relations\",\"Budget\":0.0,\"Budget_Category\":\"942 - Labor Relations\",\"Principal_Category\":\"Legal & Labor\",\"Critical_Rating\":70.0,\"Budget_Percent\":0.0},{\"index\":27,\"Site\":\"946 - Legal Counsel\",\"Budget\":1772408.0,\"Budget_Category\":\"946 - Legal Counsel\",\"Principal_Category\":\"Legal & Labor\",\"Critical_Rating\":70.0,\"Budget_Percent\":5.5210254897},{\"index\":53,\"Site\":\"990 - Procurement & Distribution\",\"Budget\":711192.0,\"Budget_Category\":\"990 - Procurement & Distribution\",\"Principal_Category\":\"Procurement\",\"Critical_Rating\":67.0,\"Budget_Percent\":2.2153528759},{\"index\":33,\"Site\":\"954 - ENG LANG LRNR/MULTILINGUAL ACH\",\"Budget\":4464195.0,\"Budget_Category\":\"954 - ENG LANG LRNR/MULTILINGUAL ACH\",\"Principal_Category\":\"ELLMA\",\"Critical_Rating\":66.0,\"Budget_Percent\":13.9059033732},{\"index\":11,\"Site\":\"918 - Facilities Planning\",\"Budget\":25240993.0,\"Budget_Category\":\"918 - Facilities Planning\",\"Principal_Category\":\"Facilities & Planning\",\"Critical_R ...

# %%
from pprint import pprint
pprint(json_obj)
# Out:
# ('{"Site":{"52":"989 - Custodial Services","51":"988 - Buildings & '
#  'Grounds","48":"983 - Payroll","25":"944 - Human Resources Services, '
#  'Supp","23":"941 - Office of the Superintendent","20":"936 - '
#  'Accounting","54":"991 - Food Service","1":"902 - Accounts Payable","5":"907 '
#  '- Student Assignment","43":"968 - Health Services (Nurses)","29":"948 - '
#  'Research Assessment & Data","24":"942 - Labor Relations","27":"946 - Legal '
#  'Counsel","53":"990 - Procurement & Distribution","33":"954 - ENG LANG '
#  'LRNR\\/MULTILINGUAL ACH","11":"918 - Facilities Planning","57":"995 - '
#  'Transportation","56":"994 - OUSD Police Department","47":"980 - CHIEF '
#  'FINANCIAL OFFICER","50":"987 - Risk Management","31":"950 - State and '
#  'Federal Programs","21":"937 - Summer Programs","13":"922 - Comm. Schools & '
#  'Student Servic","6":"909 - Teaching & Learning","7":"910 - EARLY CHILDHOOD '
#  'DEVELOPMENT","36":"958 - Communications","17":"929 - OFFICE OF '
#  'EQUITY","10":"915 - EDUCATOR EFFECTIVE","0":"901 - Chief Org Eff & '
#  'Cul.","34":"956 - Continuous School '
#  'Improvement"},"Budget":{"52":1498145.0,"51":14199558.0,"48":962511.0,"25":4761716.0,"23":1623061.0,"20":1835213.0,"54":6854385.0,"1":895003.0,"5":1787223.0,"43":3676574.0,"29":2489433.0,"24":0.0,"27":1772408.0,"53":711192.0,"33":4464195.0,"11":25240993.0,"57":12412575.0,"56":2861021.0,"47":381692.0,"50":22452934.0,"31":1443987.0,"21":2512995.0,"13":20621322.0,"6":8403763.0,"7":7484859.0,"36":2356287.0,"17":2181554.0,"10":2574796.0,"0":708859.0,"34":1346129.0},"Budget_Category":{"52":"989 '
#  '- Custodial Services","51":"988 - Buildings & Grounds","48":"983 - '
#  'Payroll","25":"944 - Human Resources Services, Supp","23":"941 - Office of '
#  'the Superintendent","20":"936 - Accounting","54":"991 - Food '
#  'Service","1":"902 - Accounts Payable","5":"907 - Student '
#  'Assignment","43":"968 - Health Services (Nurses)","29":"948 - Research '
#  'Assessment & Data","24":"942 - Labor Relations","27":"946 - Legal '
#  'Counsel","53":"990 - Procurement & Distribution","33":"954 - ENG LANG '
#  'LRNR\\/MULTILINGUAL ACH","11":"918 - Facilities Planning","57":"995 - '
#  'Transportation","56":"994 - OUSD Police Department","47":"980 - CHIEF '
#  'FINANCIAL OFFICER","50":"987 - Risk Management","31":"950 - State and '
#  'Federal Programs","21":"937 - Summer Programs","13":"922 - Comm. Schools & '
#  'Student Servic","6":"909 - Teaching & Learning","7":"910 - EARLY CHILDHOOD '
#  'DEVELOPMENT","36":"958 - Communications","17":"929 - OFFICE OF '
#  'EQUITY","10":"915 - EDUCATOR EFFECTIVE","0":"901 - Chief Org Eff & '
#  'Cul.","34":"956 - Continuous School '
#  'Improvement"},"Principal_Category":{"52":"Custodial Services","51":"Building '
#  '& Grounds","48":"Payroll","25":"Talent","23":"Superintendent\'s '
#  'Office","20":"Fiscal Services","54":"Nutrition Services","1":"Accounts '
#  'Payable","5":"School Enrollment Office","43":"Health Services '
#  '(Nurses)","29":"Research Assessment & Data","24":"Legal & Labor","27":"Legal '
#  '& Labor","53":"Procurement","33":"ELLMA","11":"Facilities & '
#  'Planning","57":"Transportation","56":"Police Services","47":"Office of '
#  'Controller & Accounting","50":"Risk Management","31":"State and '
#  'Federal","21":"Summer Learning Programs","13":"Community '
#  'Schools","6":"Academics & Instructional","7":"Early '
#  'Childhood","36":"Communications","17":"Office of '
#  'Equity","10":"Organizational Effectiveness","0":"Organizational '
#  'Effectiveness","34":"Innovations '
#  'Office"},"Critical_Rating":{"52":94.0,"51":88.0,"48":83.0,"25":83.0,"23":82.0,"20":78.0,"54":77.0,"1":77.0,"5":75.0,"43":74.0,"29":71.0,"24":70.0,"27":70.0,"53":67.0,"33":66.0,"11":64.0,"57":60.0,"56":54.0,"47":52.0,"50":52.0,"31":50.0,"21":48.0,"13":47.0,"6":45.0,"7":42.0,"36":34.0,"17":32.0,"10":17.0,"0":17.0,"34":10.0},"Budget_Percent":{"52":0.7100007303,"51":6.7294531233,"48":0.4561531179,"25":2.2566719759,"23":0.7692009086,"20":0.8697439635,"54":3.2484294614,"1":0.4241597333,"5":0.8470005474,"43":1.7424015865,"29":1.1797918412,"24":0.0,"27":0.8399794241,"53":0.3370480423,"33":2.115670853,"11":11.9622089067,"57":5.8825663166,"56":1.3558947894,"47":0.1808914349,"50":10.6408922611,"31":0.6843341763,"21":1.1909583419,"13":9.7728548832,"6":3.98271053,"7":3.5472236372,"36":1.116691302,"17":1.033881856,"10":1.2202470657,"0":0.3359423872,"34":0.6379573226}}')
